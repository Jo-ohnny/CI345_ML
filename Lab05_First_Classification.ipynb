# %% [markdown]
# Lab05_First_Classification By using KNN
#
# Date: 4/20/2026
#
# Programmer: Jean Oussou

# %%
# %matplotlib inline
import pandas as pd
#import matplotlib.pyplot as plt

# %%
#Steop 1: Load and understand your dataset

from sklearn.datasets import load_digits

digits = load_digits()
print(df.DESCR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-afafecabd393> in <module>
#       4
#       5 digits = load_digits()
# ----> 6 print(df.DESCR)
#
# NameError: name 'df' is not defined

# %%
digits = load_digits()
#digits

# %%
data = digits.data
print(data.shape)
data[0:3]
# Out:
# (1797, 64)
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#         15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#         12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#          0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#         10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.],
#        [ 0.,  0.,  0., 12., 13.,  5.,  0.,  0.,  0.,  0.,  0., 11., 16.,
#          9.,  0.,  0.,  0.,  0.,  3., 15., 16.,  6.,  0.,  0.,  0.,  7.,
#         15., 16., 16.,  2.,  0.,  0.,  0.,  0.,  1., 16., 16.,  3.,  0.,
#          0.,  0.,  0.,  1., 16., 16.,  6.,  0.,  0.,  0.,  0.,  1., 16.,
#         16.,  6.,  0.,  0.,  0.,  0.,  0., 11., 16., 10.,  0.,  0.],
#        [ 0.,  0.,  0.,  4., 15., 12.,  0.,  0.,  0.,  0.,  3., 16., 15.,
#         14.,  0.,  0.,  0.,  0.,  8., 13.,  8., 16.,  0.,  0.,  0.,  0.,
#          1.,  6., 15., 11.,  0.,  0.,  0.,  1.,  8., 13., 15.,  1.,  0.,
# ...

# %%
target = digits.target
print(target.shape)
target[3:5]
# Out:
# (1797,)
# array([3, 4])

# %%
digits.images[0]

# %%
# Step 2: Exploring data and visualization

import matplotlib.pyplot as plt

image = plt.imshow(digits.images[1])

# %%
# Counttype of realstate  and show a bar chart

import numpy as np

numbers, counts = np.unique(digits.target, return_counts = True)

plt.bar(numbers, counts, color='orange')
# Out:
# <BarContainer object of 10 artists>
