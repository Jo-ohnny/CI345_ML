# %% [markdown]
# # CI345 HW 1 ( 40 pts)
#
# # Name: Jean Oussou
#
# #Date: 04/20/26

# %% [markdown]
# ### Part A. Python Programming

# %%
# Python Programming 

# List and function
# Finish a function to user enter quarterlty sales amount.
# Finish a function to display sales
# In main fuction, invoke above functions and shw total and average sales
# Show the result as the example

QUARTER =["Spring", "Summer", "Fall", "Winter"]
           
def main():
    # create a list to hold the sales of four quarters 
    sales =[0.0] * len(QUARTER)

    inputSales(sales)
    
    print('\nDisplay the quartely sales')
    display (sales)
    
    print('\nDisplay the summary')
    print('Total sales:              $', sum(sales))
    print('Average quarterly sales   $', sum(sales)/len(QUARTER))

# Ask user to enter sales:
def inputSales(sales):
    for i in range(0, len(sales)):
        print('Enter the sales of', QUARTER[i] ,  ' : $' , end = ' ')
        sales[i] = float(input())

# 1) Finish the method here:
def display (sales):
 
    for i in range(0, len(sales)):
        print('Sales of', QUARTER[i] ,  ' : $' ,sales[i])
        

        
# Invoke 
main()
# Out:
# Enter the sales of Spring  : $ 100
# Enter the sales of Summer  : $ 200
# Enter the sales of Fall  : $ 100
# Enter the sales of Winter  : $ 100
#
# Display the quartely sales
# Sales of Spring  : $ 100.0
# Sales of Summer  : $ 200.0
# Sales of Fall  : $ 100.0
# Sales of Winter  : $ 100.0
#
# Display the summary
# Total sales:              $ 500.0
# Average quarterly sales   $ 125.0

# %% [markdown]
# ### Part B: Game Salary Data  Analysis

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
# limiting the display rows
pd.set_option('display.max_rows', 8)

# %%
gameSalary = pd.read_csv('Data/GameSalary.csv')

# %%
# 2) Show gameSalary number of rows and columns
print("Jean Oussou")
df=gameSalary
df.shape
# Out:
# Jean Oussou
# (93, 8)

# %%
# 3) display all column name
print("Jean Oussou")
df = gameSalary
df.columns
# Out:
# Jean Oussou
# Index(['ID', 'Last Name', 'First Name', 'Gender', 'Department', 'Title',
#        'Salary', 'Performance'],
#       dtype='object')

# %%
names = gameSalary.columns
for name in names:
    print(name)
# Out:
# ID
# Last Name
# First Name
# Gender
# Department
# Title
# Salary
# Performance

# %%
# 4) show the first three record
print("Jean Oussou")


gameSalary.head(3)
# Out:
# Jean Oussou
#       ID Last Name First Name Gender    Department                  Title  \
# 0  10000    Aikman       Gary      F  Sound Design  Senior Sound Designer
# 1  10387    Felser    Cynthia      F     Animation          Lead Animator
# 2  10552    Leslie       Jean      F           Art                 Artist
#
#    Salary Performance
# 0   67000     Average
# 1   80000        Good
# 2   45250     Average

# %%
# 5) display all column types

df = gameSalary

df.dtypes
# Out:
# ID              int64
# Last Name      object
# First Name     object
# Gender         object
# Department     object
# Title          object
# Salary          int64
# Performance    object
# dtype: object

# %%
# 6) Change Salary data type to float

res = gameSalary

res['Salary'] = res['Salary'].astype(float)

res.dtypes
# Out:
# ID               int64
# Last Name       object
# First Name      object
# Gender          object
# Department      object
# Title           object
# Salary         float64
# Performance     object
# dtype: object

# %%
# 7) Use basic info() 

res = gameSalary

res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           93 non-null     int64
#  1   Last Name    93 non-null     object
#  2   First Name   93 non-null     object
#  3   Gender       93 non-null     object
#  4   Department   93 non-null     object
#  5   Title        93 non-null     object
#  6   Salary       93 non-null     float64
#  7   Performance  93 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.9+ KB

# %%
# 8) show Salary column summary

res = gameSalary.Salary

print(res)
# Out:
# 0      67000
# 1      80000
# 2      45250
# 3      70125
#        ...
# 89     58400
# 90    120000
# 91     90000
# 92     75000
# Name: Salary, Length: 93, dtype: int64

# %%
# 9) show mean, min, max of Salary
print('mean', gameSalary["Salary"].mean())
print('min', gameSalary["Salary"].min())
print('Salary mean:', gameSalary.Salary.mean())

res1 = gameSalary["Salary"].mean()
res2 = gameSalary["Salary"].min()

print('Average Salary:  $' , format(res1,'.2f'))
print('Lowest Salary:   $' , format(res2,'.2f'))
# Out:
# mean 62346.18279569892
# min 35000
# Salary mean: 62346.18279569892
# Average Salary:  $ 62346.18
# Lowest Salary:   $ 35000.00

# %%
# 10) Show Famale Programmer and sorting by using  .sort_values(by='Salary')
res = gameSalary[gameSalary["Gender"] == "F"].sort_values(by="Salary")


res.head(3)
# Out:
#        ID Last Name First Name Gender         Department      Title  Salary  \
# 56  21743   Restery       Mimi      F  Quality Assurance  QA Tester   35000
# 24  15594      Ross       Fred      F  Quality Assurance  QA Tester   35000
# 59  22284     Moran       Mike      F                Art     Artist   40000
#
#    Performance
# 56     Average
# 24     Average
# 59     Average

# %%
# 11) Display Female employees's average salary

res = gameSalary[gameSalary["Gender"] == "F"]["Salary"].mean()


print('Average Salary:  $' , format(res,'.2f'))
# Out:
# Average Salary:  $ 62426.39

# %%
# 12) Display Female Programmer's average salary
res = gameSalary[(gameSalary["Gender"] == "F") & (gameSalary["Department"] == "Programming")]["Salary"].mean()


print('Average Salary:  $' , format(res,'.2f'))
# Out:
# Average Salary:  $ 77438.12

# %%
# 13) Only diplay three columns: ID, Salary, Performance 

res = gameSalary[["ID", "Salary", "Performance"]]

print(res)
# Out:
#        ID  Salary Performance
# 0   10000   67000     Average
# 1   10387   80000        Good
# 2   10552   45250     Average
# 3   10936   70125     Average
# ..    ...     ...         ...
# 89  26813   58400     Average
# 90  26896  120000   Excellent
# 91  27244   90000   Excellent
# 92  27474   75000        Good
#
# [93 rows x 3 columns]

# %%
# 14)
# A) Show all Titles name with no duplicate,       
# B) Display the title names as flowing format    

#res = gameSalary['Title'].unique()
res = gameSalary.Title.unique()
print(res)

print('\nTitles')
print('----------')
for name in res:
    print(name)
# Out:
# ['Senior Sound Designer' 'Lead Animator' 'Artist' 'Programmer'
#  'Senior Game Designer' 'Senior Programmer' 'QA Tester' 'Senior Animator'
#  'Animator' 'Sound Designer' 'Senior QA Tester' 'Senior Artist'
#  'Game Designer' 'Executive Producer' 'Producer: Product Manager'
#  'Lead Artist' 'Lead Sound Designer' 'Lead Game Designer' 'Lead QA Tester'
#  'Lead Programmer']
#
# Titles
# ----------
# Senior Sound Designer
# Lead Animator
# Artist
# Programmer
# Senior Game Designer
# Senior Programmer
# QA Tester
# Senior Animator
# Animator
# Sound Designer
# Senior QA Tester
# Senior Artist
# Game Designer
# Executive Producer
# Producer: Product Manager
# Lead Artist
# Lead Sound Designer
# Lead Game Designer
# Lead QA Tester
# Lead Programmer

# %%
# 15) Create a bar chart to compare average Salary by gender. 
# .groupby('')      
# .mean()      
# plot    

res =gameSalary.groupby("Gender")["Salary"].mean()

res.plot(kind='bar', title="Average Salary Male vs Female", color='blue')
# Out:
# <Axes: title={'center': 'Average Salary Male vs Female'}, xlabel='Gender'>

# %%
# 16)+17) 
# Create a bar chart to compare average Salary by Department. 
# .groupby('')      
# .mean()      
# plot    



res =gameSalary.groupby("Department")["Salary"].mean()

res.plot(kind='bar', title="Average Salary by Dapartment", color='green')
# Out:
# <Axes: title={'center': 'Average Salary by Dapartment'}, xlabel='Department'>

# %%
# 17) + 18) Show the number of employees for each performance level 
res = gameSalary['Performance'].value_counts()
print(res)
# and create pie chart (and show percentage)



res.plot(kind='pie', title="number of employees for each performance level")
# Out:
# Performance
# Average      38
# Good         32
# Excellent    23
# Name: count, dtype: int64
# <Axes: title={'center': 'number of employees for each performance level'}, ylabel='count'>

# %%
# 19) + 20) 
# Show the number of employee for each department,
res = gameSalary['Department'].value_counts()
print(res)
# and sorted by the values from hight to low
res1 = res.sort_values( ascending = True)

# And plot the result as bar chart
res1.plot(kind='bar', title="number of employees for each Department",color='orange')
#  .groupby('Department') or df.Department.value_counts() 
res2 = gameSalary.Department.value_counts() 

#  .sort_values(ascending=False)  
res3= res2.sort_values(ascending = False)

#  .plot 
res3.plot(kind='bar', title="number of employees for each Department",color='orange')
# Out:
# Department
# Art                  25
# Programming          25
# Animation            17
# Quality Assurance    11
# Sound Design          8
# Game Design           5
# Production            2
# Name: count, dtype: int64
# <Axes: title={'center': 'number of employees for each Department'}, xlabel='Department'>
